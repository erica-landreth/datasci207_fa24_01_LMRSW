# %% [markdown]
# # Training Models on Subsets of Imputed Data
# Erica Landreth

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
import itertools
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.11.0

# %%
data_dir = os.path.abspath(os.path.join('..', 'data'))
data = pd.read_csv(os.path.join(data_dir,'train.csv'))
data_dict = pd.read_csv(os.path.join(data_dir,'data_dictionary.csv'))

# %% [markdown]
# Start with rows that are not missing PCIAT/SII info, and filter out those columns.
#
# Also not super interested in imputing seasons.

# %%
data.dropna(subset='sii',inplace=True)
for col in data.columns:
    if 'PCIAT' in col or 'Season' in col:
        data.drop(col,axis=1,inplace=True)

# %% [markdown]
# Combined time column:

# %%
data["Fitness_Endurance-Time_Sec"].fillna(0)
data["Fitness_Endurance-Time"] = 60*data["Fitness_Endurance-Time_Mins"] + \
    data["Fitness_Endurance-Time_Sec"]
data.drop(columns=["Fitness_Endurance-Time_Mins","Fitness_Endurance-Time_Sec"])
# Out:
#             id  Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  \
# 0     00008ff9                5                0             51.0
# 1     000fd460                9                0              NaN
# 2     00105258               10                1             71.0
# 3     00115b9f                9                0             71.0
# 5     001f3379               13                1             50.0
# ...        ...              ...              ...              ...
# 3953  ff6c2bb8                8                0              NaN
# 3954  ff759544                7                1              NaN
# 3955  ff8a2de4               13                0             60.0
# 3957  ffcd4dbd               11                0             68.0
# 3958  ffed1dd5               13                0             70.0
#
#       Physical-BMI  Physical-Height  Physical-Weight  \
# 0        16.877316             46.0             50.8
# 1        14.035590             48.0             46.0
# 2        16.648696             56.5             75.6
# 3        18.292347             56.0             81.6
# 5        22.279952             59.5            112.2
# ...            ...              ...              ...
# 3953     17.139810             52.5             67.2
# 3954     13.927006             48.5             46.6
# 3955     16.362460             59.5             82.4
# 3957     21.441500             60.0            109.8
# 3958     12.235895             70.7             87.0
#
#       Physical-Waist_Circumference  Physical-Diastolic_BP  Physical-HeartRate  \
# 0                              NaN                    NaN                 NaN
# 1                             22.0                   75.0                70.0
# 2                              NaN                   65.0                94.0
# 3                              NaN                   60.0                97.0
# 5                              NaN                   60.0                73.0
# ...                            ...                    ...                 ...
# 3953                          25.0                   60.0                65.0
# 3954                          23.0                   65.0                75.0
# 3955                           NaN                   71.0                70.0
# 3957                           NaN                   79.0                99.0
# 3958                           NaN                   59.0                61.0
#
#       ...  BIA-BIA_LST  BIA-BIA_SMM  BIA-BIA_TBW  PAQ_A-PAQ_A_Total  \
# 0     ...      38.9177      19.5413      32.6909                NaN
# 1     ...      39.4497      15.4107      27.0552                NaN
# 2     ...          NaN          NaN          NaN                NaN
# 3     ...      58.9338      26.4798      45.9966                NaN
# 5     ...      79.6982      35.3804      63.1265                NaN
# ...   ...          ...          ...          ...                ...
# 3953  ...      49.3301      20.2645      36.7181                NaN
# 3954  ...      42.8185      18.0937      30.0453                NaN
# 3955  ...      66.2889      29.7790      52.8320                NaN
# 3957  ...      71.3903      28.7792      54.4630                NaN
# 3958  ...      86.2475      45.4340      67.9038                NaN
#
#       PAQ_C-PAQ_C_Total  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0                   NaN                NaN              NaN
# 1                 2.340               46.0             64.0
# 2                 2.170               38.0             54.0
# 3                 2.451               31.0             45.0
# 5                 4.110               40.0             56.0
# ...                 ...                ...              ...
# 3953              3.440               41.0             58.0
# 3954                NaN               48.0             67.0
# 3955              3.260               35.0             50.0
# 3957              2.729               56.0             77.0
# 3958              3.300               33.0             47.0
#
#       PreInt_EduHx-computerinternet_hoursday  sii  Fitness_Endurance-Time
# 0                                        3.0  2.0                     NaN
# 1                                        0.0  0.0                     NaN
# 2                                        2.0  0.0                   453.0
# 3                                        0.0  1.0                   577.0
# 5                                        0.0  1.0                     NaN
# ...                                      ...  ...                     ...
# 3953                                     2.0  0.0                     NaN
# 3954                                     0.0  1.0                     NaN
# 3955                                     1.0  1.0                     NaN
# 3957                                     0.0  1.0                     NaN
# 3958                                     1.0  0.0                     NaN
#
# [2736 rows x 49 columns]

# %%
# PAQ: usually only child or adult filled in, so make a combined column

data['PAQ'] = data['PAQ_A-PAQ_A_Total'].fillna(data['PAQ_C-PAQ_C_Total'])
data.drop('PAQ_A-PAQ_A_Total',axis=1,inplace=True)
data.drop('PAQ_C-PAQ_C_Total',axis=1,inplace=True)

# %%
# fix BIA outliers

# note: reasonable values were determined by looking at histogram plots of the fields,
# for various bin sizes until it was apparent which were outliers
# extension: use outlier detection algorithm instead of hand-crafted cutoffs

data['BIA-BIA_BMC'] = data['BIA-BIA_BMC'].mask(data['BIA-BIA_BMC'] > 20, pd.NA)
data['BIA-BIA_BMR'] = data['BIA-BIA_BMR'].mask(data['BIA-BIA_BMR'] > 2500, pd.NA)
data['BIA-BIA_DEE'] = data['BIA-BIA_DEE'].mask(data['BIA-BIA_DEE'] > 4000, pd.NA)
data['BIA-BIA_ECW'] = data['BIA-BIA_ECW'].mask(data['BIA-BIA_ECW'] > 80, pd.NA)
data['BIA-BIA_FFM'] = data['BIA-BIA_FFM'].mask(data['BIA-BIA_FFM'] > 200, pd.NA)
data['BIA-BIA_FFMI'] = data['BIA-BIA_FFMI'].mask(data['BIA-BIA_FFMI'] > 25, pd.NA)
data['BIA-BIA_FMI'] = data['BIA-BIA_FMI'].mask(data['BIA-BIA_FMI'] < 0, pd.NA)
data['BIA-BIA_Fat'] = data['BIA-BIA_Fat'].mask(data['BIA-BIA_Fat'] < 0, pd.NA)
data['BIA-BIA_Fat'] = data['BIA-BIA_Fat'].mask(data['BIA-BIA_Fat'] > 100, pd.NA)
data['BIA-BIA_ICW'] = data['BIA-BIA_ICW'].mask(data['BIA-BIA_ICW'] > 100, pd.NA)
data['BIA-BIA_LDM'] = data['BIA-BIA_LDM'].mask(data['BIA-BIA_LDM'] > 50, pd.NA)
data['BIA-BIA_LST'] = data['BIA-BIA_LST'].mask(data['BIA-BIA_LST'] > 150, pd.NA)
data['BIA-BIA_SMM'] = data['BIA-BIA_SMM'].mask(data['BIA-BIA_SMM'] > 100, pd.NA)
data['BIA-BIA_TBW'] = data['BIA-BIA_TBW'].mask(data['BIA-BIA_TBW'] > 125, pd.NA)

# %%
data.reset_index(inplace=True,drop=True)
data["idx_orig"] = data.index
data_orig = data.copy()
sii_orig = data.loc[:,'sii']

# %% [markdown]
# ### Basic Imputation

# %%
data.head()
# Out:
#          id  Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  Physical-BMI  \
# 0  00008ff9                5                0             51.0     16.877316
# 1  000fd460                9                0              NaN     14.035590
# 2  00105258               10                1             71.0     16.648696
# 3  00115b9f                9                0             71.0     18.292347
# 4  001f3379               13                1             50.0     22.279952
#
#    Physical-Height  Physical-Weight  Physical-Waist_Circumference  \
# 0             46.0             50.8                           NaN
# 1             48.0             46.0                          22.0
# 2             56.5             75.6                           NaN
# 3             56.0             81.6                           NaN
# 4             59.5            112.2                           NaN
#
#    Physical-Diastolic_BP  Physical-HeartRate  ...  BIA-BIA_LST  BIA-BIA_SMM  \
# 0                    NaN                 NaN  ...      38.9177      19.5413
# 1                   75.0                70.0  ...      39.4497      15.4107
# 2                   65.0                94.0  ...          NaN          NaN
# 3                   60.0                97.0  ...      58.9338      26.4798
# 4                   60.0                73.0  ...      79.6982      35.3804
#
#    BIA-BIA_TBW  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0      32.6909                NaN              NaN
# 1      27.0552               46.0             64.0
# 2          NaN               38.0             54.0
# 3      45.9966               31.0             45.0
# 4      63.1265               40.0             56.0
#
#    PreInt_EduHx-computerinternet_hoursday  sii  Fitness_Endurance-Time    PAQ  \
# 0                                     3.0  2.0                     NaN    NaN
# 1                                     0.0  0.0                     NaN  2.340
# 2                                     2.0  0.0                   453.0  2.170
# 3                                     0.0  1.0                   577.0  2.451
# 4                                     0.0  1.0                     NaN  4.110
#
#    idx_orig
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#
# [5 rows x 51 columns]

# %%
is_missing = data.isna().sum(axis=0).to_frame()
is_missing
# Out:
#                                            0
# id                                         0
# Basic_Demos-Age                            0
# Basic_Demos-Sex                            0
# CGAS-CGAS_Score                          394
# Physical-BMI                             209
# Physical-Height                          206
# Physical-Weight                          164
# Physical-Waist_Circumference            2253
# Physical-Diastolic_BP                    258
# Physical-HeartRate                       250
# Physical-Systolic_BP                     258
# Fitness_Endurance-Max_Stage             2005
# Fitness_Endurance-Time_Mins             2008
# Fitness_Endurance-Time_Sec              2008
# FGC-FGC_CU                               817
# FGC-FGC_CU_Zone                          852
# FGC-FGC_GSND                            1864
# FGC-FGC_GSND_Zone                       1872
# FGC-FGC_GSD                             1865
# FGC-FGC_GSD_Zone                        1872
# FGC-FGC_PU                               827
# FGC-FGC_PU_Zone                          861
# FGC-FGC_SRL                              825
# FGC-FGC_SRL_Zone                         859
# FGC-FGC_SRR                              823
# FGC-FGC_SRR_Zone                         857
# FGC-FGC_TL                               817
# FGC-FGC_TL_Zone                          851
# BIA-BIA_Activity_Level_num               923
# BIA-BIA_BMC                              928
# BIA-BIA_BMI                              923
# BIA-BIA_BMR                              933
# BIA-BIA_DEE                              939
# BIA-BIA_ECW                              932
# BIA-BIA_FFM                              933
# BIA-BIA_FFMI                             938
# BIA-BIA_FMI                              954
# BIA-BIA_Fat                              973
# BIA-BIA_Frame_num                        923
# BIA-BIA_ICW                              932
# BIA-BIA_LDM                              936
# BIA-BIA_LST                              950
# BIA-BIA_SMM                              938
# BIA-BIA_TBW                              942
# SDS-SDS_Total_Raw                        209
# SDS-SDS_Total_T                          211
# PreInt_EduHx-computerinternet_hoursday    82
# sii                                        0
# Fitness_Endurance-Time                  2009
# PAQ                                      934
# idx_orig                                   0

# %% [markdown]
# **PAQ: From data dictionary definition, seems like only adult or child field will be filled in. So combine them.**

# %% [markdown]
# **Physical: height/weight info probably not as informative as BMI, so use that instead. Also, can fill from BIA BMI if stil missing (and vice versa: fill BIA BMI from Physical BMI).**

# %%
data.head()
# Out:
#          id  Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  Physical-BMI  \
# 0  00008ff9                5                0             51.0     16.877316
# 1  000fd460                9                0              NaN     14.035590
# 2  00105258               10                1             71.0     16.648696
# 3  00115b9f                9                0             71.0     18.292347
# 4  001f3379               13                1             50.0     22.279952
#
#    Physical-Height  Physical-Weight  Physical-Waist_Circumference  \
# 0             46.0             50.8                           NaN
# 1             48.0             46.0                          22.0
# 2             56.5             75.6                           NaN
# 3             56.0             81.6                           NaN
# 4             59.5            112.2                           NaN
#
#    Physical-Diastolic_BP  Physical-HeartRate  ...  BIA-BIA_LST  BIA-BIA_SMM  \
# 0                    NaN                 NaN  ...      38.9177      19.5413
# 1                   75.0                70.0  ...      39.4497      15.4107
# 2                   65.0                94.0  ...          NaN          NaN
# 3                   60.0                97.0  ...      58.9338      26.4798
# 4                   60.0                73.0  ...      79.6982      35.3804
#
#    BIA-BIA_TBW  SDS-SDS_Total_Raw  SDS-SDS_Total_T  \
# 0      32.6909                NaN              NaN
# 1      27.0552               46.0             64.0
# 2          NaN               38.0             54.0
# 3      45.9966               31.0             45.0
# 4      63.1265               40.0             56.0
#
#    PreInt_EduHx-computerinternet_hoursday  sii  Fitness_Endurance-Time    PAQ  \
# 0                                     3.0  2.0                     NaN    NaN
# 1                                     0.0  0.0                     NaN  2.340
# 2                                     2.0  0.0                   453.0  2.170
# 3                                     0.0  1.0                   577.0  2.451
# 4                                     0.0  1.0                     NaN  4.110
#
#    idx_orig
# 0         0
# 1         1
# 2         2
# 3         3
# 4         4
#
# [5 rows x 51 columns]

# %%
data['calc-BMI'] = data['Physical-Weight']*0.453592 / (data['Physical-Height']*0.0254)**2
                        #weight kg/height m squared
data['Physical-BMI'] = data['Physical-BMI'].fillna(data['calc-BMI'])
data['Physical-BMI'] = data['Physical-BMI'].fillna(data['BIA-BIA_BMI'])

# and fill the other way around too
data['BIA-BIA_BMI'] = data['BIA-BIA_BMI'].fillna(data['Physical-BMI'])

data.drop('Physical-Height',axis=1,inplace=True)
data.drop('Physical-Weight',axis=1,inplace=True)
data.drop('calc-BMI',axis=1,inplace=True)

# %% [markdown]
# **FitnessGram: Zones are derived from values and age. For now, we'll drop the zones entirely, since they contain somewhat redundant info, and they tend to be missing more often than the values themselves.**
#
# **Possible extension: Instead of zones (which tend to take only 2-3 values), create some sort of "age-adjusted" value column, which takes into account age, but is more descriptive than zone**

# %% [markdown]
# EDA: visualizing FitnessGram zones vs values, colored by age.

# %%
base = ['CU','GSND','GSD','PU','SRL','SRR','TL']
for b in base:
    f1 = f'FGC-FGC_{b}'
    f2 = f1+'_Zone'
    fig,ax = plt.subplots(1,1)
    s = ax.scatter(f1,f2,c='Basic_Demos-Age',data=data,alpha=0.1)
    ax.set_xlabel(f'{b} Value')
    ax.set_ylabel(f'{b} Zone')
    ax.set_title(f'FitnessGram {b} zone vs value')
    c = plt.colorbar(s, ax=ax)
    c.set_label('Age')
    plt.show()

# %%
data.drop([col for col in data.columns if '_Zone' in col],axis=1,inplace=True)

# %% [markdown]
# Checking in: what does data look like, and what are we still missing?

# %%
data
# Out:
#             id  Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  \
# 0     00008ff9                5                0             51.0
# 1     000fd460                9                0              NaN
# 2     00105258               10                1             71.0
# 3     00115b9f                9                0             71.0
# 4     001f3379               13                1             50.0
# ...        ...              ...              ...              ...
# 2731  ff6c2bb8                8                0              NaN
# 2732  ff759544                7                1              NaN
# 2733  ff8a2de4               13                0             60.0
# 2734  ffcd4dbd               11                0             68.0
# 2735  ffed1dd5               13                0             70.0
#
#       Physical-BMI  Physical-Waist_Circumference  Physical-Diastolic_BP  \
# 0        16.877316                           NaN                    NaN
# 1        14.035590                          22.0                   75.0
# 2        16.648696                           NaN                   65.0
# 3        18.292347                           NaN                   60.0
# 4        22.279952                           NaN                   60.0
# ...            ...                           ...                    ...
# 2731     17.139810                          25.0                   60.0
# 2732     13.927006                          23.0                   65.0
# 2733     16.362460                           NaN                   71.0
# 2734     21.441500                           NaN                   79.0
# 2735     12.235895                           NaN                   59.0
#
#       Physical-HeartRate  Physical-Systolic_BP  Fitness_Endurance-Max_Stage  \
# 0                    NaN                   NaN                          NaN
# 1                   70.0                 122.0                          NaN
# 2                   94.0                 117.0                          5.0
# 3                   97.0                 117.0                          6.0
# 4                   73.0                 102.0                          NaN
# ...                  ...                   ...                          ...
# 2731                65.0                 112.0                          NaN
# 2732                75.0                 105.0                          NaN
# 2733                70.0                 104.0                          NaN
# 2734                99.0                 116.0                          NaN
# 2735                61.0                 113.0                          NaN
#
#       ...  BIA-BIA_LST  BIA-BIA_SMM  BIA-BIA_TBW  SDS-SDS_Total_Raw  \
# 0     ...      38.9177      19.5413      32.6909                NaN
# 1     ...      39.4497      15.4107      27.0552               46.0
# 2     ...          NaN          NaN          NaN               38.0
# 3     ...      58.9338      26.4798      45.9966               31.0
# 4     ...      79.6982      35.3804      63.1265               40.0
# ...   ...          ...          ...          ...                ...
# 2731  ...      49.3301      20.2645      36.7181               41.0
# 2732  ...      42.8185      18.0937      30.0453               48.0
# 2733  ...      66.2889      29.7790      52.8320               35.0
# 2734  ...      71.3903      28.7792      54.4630               56.0
# 2735  ...      86.2475      45.4340      67.9038               33.0
#
#       SDS-SDS_Total_T  PreInt_EduHx-computerinternet_hoursday  sii  \
# 0                 NaN                                     3.0  2.0
# 1                64.0                                     0.0  0.0
# 2                54.0                                     2.0  0.0
# 3                45.0                                     0.0  1.0
# 4                56.0                                     0.0  1.0
# ...               ...                                     ...  ...
# 2731             58.0                                     2.0  0.0
# 2732             67.0                                     0.0  1.0
# 2733             50.0                                     1.0  1.0
# 2734             77.0                                     0.0  1.0
# 2735             47.0                                     1.0  0.0
#
#       Fitness_Endurance-Time    PAQ  idx_orig
# 0                        NaN    NaN         0
# 1                        NaN  2.340         1
# 2                      453.0  2.170         2
# 3                      577.0  2.451         3
# 4                        NaN  4.110         4
# ...                      ...    ...       ...
# 2731                     NaN  3.440      2731
# 2732                     NaN    NaN      2732
# 2733                     NaN  3.260      2733
# 2734                     NaN  2.729      2734
# 2735                     NaN  3.300      2735
#
# [2736 rows x 42 columns]

# %%
is_missing = data.isna().mean(axis=0).to_frame().sort_values(by=0,ascending=False)
is_missing
# below table: proportion of data missing each field
# Out:
#                                                0
# Physical-Waist_Circumference            0.823465
# Fitness_Endurance-Time                  0.734284
# Fitness_Endurance-Time_Mins             0.733918
# Fitness_Endurance-Time_Sec              0.733918
# Fitness_Endurance-Max_Stage             0.732822
# FGC-FGC_GSD                             0.681652
# FGC-FGC_GSND                            0.681287
# BIA-BIA_Fat                             0.355629
# BIA-BIA_FMI                             0.348684
# BIA-BIA_LST                             0.347222
# BIA-BIA_TBW                             0.344298
# BIA-BIA_DEE                             0.343202
# BIA-BIA_FFMI                            0.342836
# BIA-BIA_SMM                             0.342836
# BIA-BIA_LDM                             0.342105
# PAQ                                     0.341374
# BIA-BIA_BMR                             0.341009
# BIA-BIA_FFM                             0.341009
# BIA-BIA_ECW                             0.340643
# BIA-BIA_ICW                             0.340643
# BIA-BIA_BMC                             0.339181
# BIA-BIA_Frame_num                       0.337354
# BIA-BIA_Activity_Level_num              0.337354
# FGC-FGC_PU                              0.302266
# FGC-FGC_SRL                             0.301535
# FGC-FGC_SRR                             0.300804
# FGC-FGC_TL                              0.298611
# FGC-FGC_CU                              0.298611
# CGAS-CGAS_Score                         0.144006
# Physical-Systolic_BP                    0.094298
# Physical-Diastolic_BP                   0.094298
# Physical-HeartRate                      0.091374
# SDS-SDS_Total_T                         0.077120
# SDS-SDS_Total_Raw                       0.076389
# BIA-BIA_BMI                             0.074196
# Physical-BMI                            0.074196
# PreInt_EduHx-computerinternet_hoursday  0.029971
# sii                                     0.000000
# id                                      0.000000
# Basic_Demos-Age                         0.000000
# Basic_Demos-Sex                         0.000000
# idx_orig                                0.000000

# %% [markdown]
# We'll choose to drop any fields that are missing at least half the time.

# %%
data.drop(list(is_missing[is_missing > 0.5].dropna().index),axis=1,inplace=True)

# %% [markdown]
# Store "basic imputation" level data:

# %%
data.reset_index(inplace=True,drop=True)
data_basic_impute= data.copy()

# %% [markdown]
# ### KNN Imputation

# %% [markdown]
# Since the holes vary so much from record to record, going to brute force it for now and loop through all columns for all records.
#
# Extension: think about a more clever way to do this

# %%
# define column groups

cols = list(data_orig.columns)
col_groups = {}

tests = ["Basic_Demos","CGAS","Physical","Fitness_Endurance","FGC","BIA","PAQ","SDS","PreInt"]
for test in tests:
    col_groups[test] = [col for col in data.columns if test in col]
col_groups["PAQ"] = ["PAQ"]

print(col_groups)

feat_cols = list(itertools.chain.from_iterable(col_groups.values()))
print(feat_cols)
# Out:
# {'Basic_Demos': ['Basic_Demos-Age', 'Basic_Demos-Sex'], 'CGAS': ['CGAS-CGAS_Score'], 'Physical': ['Physical-BMI', 'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP'], 'Fitness_Endurance': [], 'FGC': ['FGC-FGC_CU', 'FGC-FGC_PU', 'FGC-FGC_SRL', 'FGC-FGC_SRR', 'FGC-FGC_TL'], 'BIA': ['BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI', 'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM', 'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num', 'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM', 'BIA-BIA_TBW'], 'PAQ': ['PAQ'], 'SDS': ['SDS-SDS_Total_Raw', 'SDS-SDS_Total_T'], 'PreInt': ['PreInt_EduHx-computerinternet_hoursday']}
# ['Basic_Demos-Age', 'Basic_Demos-Sex', 'CGAS-CGAS_Score', 'Physical-BMI', 'Physical-Diastolic_BP', 'Physical-HeartRate', 'Physical-Systolic_BP', 'FGC-FGC_CU', 'FGC-FGC_PU', 'FGC-FGC_SRL', 'FGC-FGC_SRR', 'FGC-FGC_TL', 'BIA-BIA_Activity_Level_num', 'BIA-BIA_BMC', 'BIA-BIA_BMI', 'BIA-BIA_BMR', 'BIA-BIA_DEE', 'BIA-BIA_ECW', 'BIA-BIA_FFM', 'BIA-BIA_FFMI', 'BIA-BIA_FMI', 'BIA-BIA_Fat', 'BIA-BIA_Frame_num', 'BIA-BIA_ICW', 'BIA-BIA_LDM', 'BIA-BIA_LST', 'BIA-BIA_SMM', 'BIA-BIA_TBW', 'PAQ', 'SDS-SDS_Total_Raw', 'SDS-SDS_Total_T', 'PreInt_EduHx-computerinternet_hoursday']

# %%
N = 3

for idx in range(data.shape[0]):
    item = data.loc[[idx]]
    sii = item.sii.values[0]
    item = item[feat_cols]

    is_missing = item.isnull().any()
    missing_cols = is_missing[is_missing].index.tolist()
    feat_data = item.dropna(axis=1)

    for col in missing_cols:
        use_me = [col for col in feat_data.columns if col in data_basic_impute.columns] + [col]
        feat_ref = data_basic_impute.loc[data['sii'] == sii, use_me].dropna()
        if feat_ref.shape[0] == 0:
            print("No data")
        if feat_ref.shape[0] < 5:
            print('!!!')
            continue
        x = feat_ref[list(feat_data.columns)]
        y = feat_ref[col]
        if col == 'PAQ':
            knn = KNeighborsRegressor(n_neighbors=N)
        elif 'categorical' in data_dict.Type[data_dict.Field == col].values[0]:
            knn = KNeighborsClassifier(n_neighbors=N)
        else:
            knn = KNeighborsRegressor(n_neighbors=N)
        knn.fit(x,y.values)
        y_fill = knn.predict(feat_data)
        data.loc[idx,col] = y_fill

# %% [markdown]
# Double check that everything was imputed (i.e. no more missing values)

# %%
data.shape == data.dropna().shape
# Out:
# True

# %%
data_knn_impute = data.copy()
data_knn_impute
# Out:
#             id  Basic_Demos-Age  Basic_Demos-Sex  CGAS-CGAS_Score  \
# 0     00008ff9                5                0        51.000000
# 1     000fd460                9                0        68.333333
# 2     00105258               10                1        71.000000
# 3     00115b9f                9                0        71.000000
# 4     001f3379               13                1        50.000000
# ...        ...              ...              ...              ...
# 2731  ff6c2bb8                8                0        62.666667
# 2732  ff759544                7                1        60.333333
# 2733  ff8a2de4               13                0        60.000000
# 2734  ffcd4dbd               11                0        68.000000
# 2735  ffed1dd5               13                0        70.000000
#
#       Physical-BMI  Physical-Diastolic_BP  Physical-HeartRate  \
# 0        16.877316              57.666667           89.666667
# 1        14.035590              75.000000           70.000000
# 2        16.648696              65.000000           94.000000
# 3        18.292347              60.000000           97.000000
# 4        22.279952              60.000000           73.000000
# ...            ...                    ...                 ...
# 2731     17.139810              60.000000           65.000000
# 2732     13.927006              65.000000           75.000000
# 2733     16.362460              71.000000           70.000000
# 2734     21.441500              79.000000           99.000000
# 2735     12.235895              59.000000           61.000000
#
#       Physical-Systolic_BP  FGC-FGC_CU  FGC-FGC_PU  ...  BIA-BIA_LDM  \
# 0               113.333333    0.000000    0.000000  ...      8.89536
# 1               122.000000    3.000000    5.000000  ...     14.97400
# 2               117.000000   20.000000    7.000000  ...     13.98280
# 3               117.000000   18.000000    5.000000  ...     16.77900
# 4               102.000000   12.000000    6.000000  ...     20.90200
# ...                    ...         ...         ...  ...          ...
# 2731            112.000000    0.000000    0.000000  ...     15.81500
# 2732            105.000000    0.000000    0.000000  ...     15.14000
# 2733            104.000000   16.000000   10.000000  ...     17.97970
# 2734            116.000000   15.000000    0.000000  ...     21.34030
# 2735            113.000000   29.333333   22.333333  ...     25.00540
#
#       BIA-BIA_LST  BIA-BIA_SMM  BIA-BIA_TBW  SDS-SDS_Total_Raw  \
# 0         38.9177      19.5413    32.690900          51.333333
# 1         39.4497      15.4107    27.055200          46.000000
# 2         50.8585      23.5805    40.767467          38.000000
# 3         58.9338      26.4798    45.996600          31.000000
# 4         79.6982      35.3804    63.126500          40.000000
# ...           ...          ...          ...                ...
# 2731      49.3301      20.2645    36.718100          41.000000
# 2732      42.8185      18.0937    30.045300          48.000000
# 2733      66.2889      29.7790    52.832000          35.000000
# 2734      71.3903      28.7792    54.463000          56.000000
# 2735      86.2475      45.4340    67.903800          33.000000
#
#       SDS-SDS_Total_T  PreInt_EduHx-computerinternet_hoursday  sii       PAQ  \
# 0           71.333333                                     3.0  2.0  2.730333
# 1           64.000000                                     0.0  0.0  2.340000
# 2           54.000000                                     2.0  0.0  2.170000
# 3           45.000000                                     0.0  1.0  2.451000
# 4           56.000000                                     0.0  1.0  4.110000
# ...               ...                                     ...  ...       ...
# 2731        58.000000                                     2.0  0.0  3.440000
# 2732        67.000000                                     0.0  1.0  3.116667
# 2733        50.000000                                     1.0  1.0  3.260000
# 2734        77.000000                                     0.0  1.0  2.729000
# 2735        47.000000                                     1.0  0.0  3.300000
#
#       idx_orig
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ...        ...
# 2731      2731
# 2732      2732
# 2733      2733
# 2734      2734
# 2735      2735
#
# [2736 rows x 35 columns]

# %% [markdown]
# # Split into train, test, val

# %% [markdown]
# First, define shuffled indices for train, validation, and test data that we'll use to train each model.

# %%
# train/val/test split
split = (0.6, 0.2, 0.2)

# original dataset index
idx = np.array(data_orig.index)

# set seed
tf.random.set_seed(1234)
np.random.seed(1234)

# shuffle index
idx_shuffled = np.random.permutation(idx)

# create random splits
splits = np.multiply(len(idx), split).astype(int)
idx_train, idx_val, idx_test = np.split(idx_shuffled, [splits[0], splits[0]+splits[1]])

# %%
def get_data( feat_cols, X, y=sii_orig, idx_train=idx_train, \
             idx_val=idx_val, idx_test=idx_test, verbose=True):
    
    X = X[feat_cols + ["idx_orig"]].dropna()
    idx_orig = X.idx_orig
    X = X[feat_cols]

    idx_train = np.intersect1d(idx_train, idx_orig)
    idx_val = np.intersect1d(idx_val, idx_orig)
    idx_test = np.intersect1d(idx_test, idx_orig)

    X_train = X[idx_orig.isin(idx_train)]
    X_val = X[idx_orig.isin(idx_val)]
    X_test = X[idx_orig.isin(idx_test)]

    y_train = y[idx_train]
    y_val = y[idx_val]
    y_test = y[idx_test]

    if verbose:
        print("X_train shape",X_train.shape)
        print("X_val shape",X_val.shape)
        print("X_test shape",X_test.shape)
        print("y_train shape",y_train.shape)
        print("y_val shape",y_val.shape)
        print("y_test shape",y_test.shape)

    return X_train, y_train, X_val, y_val, X_test, y_test

# %%
def build_multiclass_model(X_train, learning_rate = 0.001):
    tf.keras.backend.clear_session()
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(
        units=4,                     # output dim
        input_shape=[X_train.shape[1]],             # input dim
        use_bias=False,              # we included the bias in X
        activation='softmax',        # apply a sigmoid to the output
        kernel_initializer=tf.ones_initializer,  # initialize params to 1
    ))
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer)

    return model

# %% [markdown]
# # Column Group Models

# %%
list(col_groups.keys())
# Out:
# ['Basic_Demos',
#  'CGAS',
#  'Physical',
#  'Fitness_Endurance',
#  'FGC',
#  'BIA',
#  'PAQ',
#  'SDS',
#  'PreInt']

# %%
use_me = np.intersect1d(idx_train, data_orig.idx_orig)
data_ref = data_orig[data_orig.idx_orig.isin(use_me)]

# %%
col_names = list(col_groups.keys())
row_names = ['n_orig', 'data_orig', 'n_basic_impute', 'data_basic_impute', 'n_knn_impute', 'data_knn_impute']
results = np.full((len(row_names),len(col_names)),np.nan)
results = pd.DataFrame(results, columns=col_names, index=row_names)

# %% [markdown]
# ### Basic Demographics

# %%
grp = "Basic_Demos"

# %%
# pre-processing:

# Basic_Demos-Age: use min/max scaler
scaler = MinMaxScaler()
scaler.fit(data_ref[["Basic_Demos-Age"]])
data_orig["Basic_Demos-Age"] = scaler.transform(data_orig[["Basic_Demos-Age"]])
data_basic_impute["Basic_Demos-Age"] = scaler.transform(data_basic_impute[["Basic_Demos-Age"]])
data_knn_impute["Basic_Demos-Age"] = scaler.transform(data_knn_impute[["Basic_Demos-Age"]])

# sex: already binary

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 2)
# X_val shape (547, 2)
# X_test shape (548, 2)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)
# Out:
# 2024-11-30 16:07:13.418588: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 294us/step
# Test accuracy: 0.43795620437956206
# 18/18 [==============================] - 0s 326us/step - loss: 1.0960
# Test loss: 1.0959891080856323

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 2)
# X_val shape (547, 2)
# X_test shape (548, 2)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 300us/step
# Test accuracy: 0.43795620437956206
# 18/18 [==============================] - 0s 340us/step - loss: 1.0960
# Test loss: 1.0959891080856323

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 2)
# X_val shape (547, 2)
# X_test shape (548, 2)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 300us/step
# Test accuracy: 0.43795620437956206
# 18/18 [==============================] - 0s 331us/step - loss: 1.0960
# Test loss: 1.0959891080856323

# %% [markdown]
# ### CGAS Score

# %%
grp = "CGAS"

# %%
# pre-processing:

# CGAS-CGAS_Score: scale from 0 to 100
data_orig["CGAS-CGAS_Score"] = data_orig[["CGAS-CGAS_Score"]]/100
data_basic_impute["CGAS-CGAS_Score"] = data_basic_impute[["CGAS-CGAS_Score"]]/100
data_knn_impute["CGAS-CGAS_Score"] = data_knn_impute[["CGAS-CGAS_Score"]]/100

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1406, 1)
# X_val shape (471, 1)
# X_test shape (465, 1)
# y_train shape (1406,)
# y_val shape (471,)
# y_test shape (465,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 15/15 [==============================] - 0s 323us/step
# Test accuracy: 0.5956989247311828
# 15/15 [==============================] - 0s 343us/step - loss: 0.9707
# Test loss: 0.9706771373748779

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1406, 1)
# X_val shape (471, 1)
# X_test shape (465, 1)
# y_train shape (1406,)
# y_val shape (471,)
# y_test shape (465,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 15/15 [==============================] - 0s 303us/step
# Test accuracy: 0.5956989247311828
# 15/15 [==============================] - 0s 345us/step - loss: 0.9707
# Test loss: 0.9706771373748779

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 1)
# X_val shape (547, 1)
# X_test shape (548, 1)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 307us/step
# Test accuracy: 0.6040145985401459
# 18/18 [==============================] - 0s 339us/step - loss: 0.9585
# Test loss: 0.9584823846817017

# %% [markdown]
# ### Physical

# %%
grp = "Physical"

# %%
# pre-processing: all columns can be scaled using standard scaler

for col in col_groups["Physical"]:
    scaler = StandardScaler()
    scaler.fit(data_ref[[col]])
    data_orig[col] = scaler.transform(data_orig[[col]])
    data_basic_impute[col] = scaler.transform(data_basic_impute[[col]])
    data_knn_impute[col] = scaler.transform(data_knn_impute[[col]])

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1480, 4)
# X_val shape (483, 4)
# X_test shape (501, 4)
# y_train shape (1480,)
# y_val shape (483,)
# y_test shape (501,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 16/16 [==============================] - 0s 308us/step
# Test accuracy: 0.4930139720558882
# 16/16 [==============================] - 0s 374us/step - loss: 1.3419
# Test loss: 1.341915488243103

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1481, 4)
# X_val shape (483, 4)
# X_test shape (501, 4)
# y_train shape (1481,)
# y_val shape (483,)
# y_test shape (501,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 16/16 [==============================] - 0s 302us/step
# Test accuracy: 0.49700598802395207
# 16/16 [==============================] - 0s 368us/step - loss: 1.3417
# Test loss: 1.3416659832000732

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 4)
# X_val shape (547, 4)
# X_test shape (548, 4)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 293us/step
# Test accuracy: 0.5036496350364964
# 18/18 [==============================] - 0s 352us/step - loss: 1.3410
# Test loss: 1.3410499095916748

# %% [markdown]
# ### Fitness Endurance

# %%
grp = "Fitness_Endurance"

# %%
# pre-processing (original data ONLY):

# Fitness_Endurance-Max_Stage: use standard scaler
scaler = StandardScaler()
scaler.fit(data_ref[["Fitness_Endurance-Max_Stage"]])
data_orig["Fitness_Endurance-Max_Stage"] = scaler.transform(data_orig[["Fitness_Endurance-Max_Stage"]])

# scale
scaler = StandardScaler()
scaler.fit(data_ref[["Fitness_Endurance-Time"]])
data_orig["Fitness_Endurance-Time"] = scaler.transform(data_orig[["Fitness_Endurance-Time"]])

# reset column group definition for fitness endurance
col_groups["Fitness_Endurance"] = ["Fitness_Endurance-Max_Stage","Fitness_Endurance-Time"]

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (443, 2)
# X_val shape (133, 2)
# X_test shape (151, 2)
# y_train shape (443,)
# y_val shape (133,)
# y_test shape (151,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 5/5 [==============================] - 0s 489us/step
# Test accuracy: 0.33774834437086093
# 5/5 [==============================] - 0s 530us/step - loss: 1.3911
# Test loss: 1.391130805015564

# %% [markdown]
# ### FGC

# %%
grp = "FGC"

# %%
# pre-processing: all columns can be scaled using standard scaler

for col in col_groups["FGC"]:
    scaler = StandardScaler()
    scaler.fit(data_ref[[col]])
    data_orig[col] = scaler.transform(data_orig[[col]])
    data_basic_impute[col] = scaler.transform(data_basic_impute[[col]])
    data_knn_impute[col] = scaler.transform(data_knn_impute[[col]])

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1156, 5)
# X_val shape (365, 5)
# X_test shape (380, 5)
# y_train shape (1156,)
# y_val shape (365,)
# y_test shape (380,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 12/12 [==============================] - 0s 338us/step
# Test accuracy: 0.55
# 12/12 [==============================] - 0s 366us/step - loss: 1.3295
# Test loss: 1.3294986486434937

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1156, 5)
# X_val shape (365, 5)
# X_test shape (380, 5)
# y_train shape (1156,)
# y_val shape (365,)
# y_test shape (380,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 12/12 [==============================] - 0s 358us/step
# Test accuracy: 0.55
# 12/12 [==============================] - 0s 378us/step - loss: 1.3295
# Test loss: 1.3294986486434937

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 5)
# X_val shape (547, 5)
# X_test shape (548, 5)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 318us/step
# Test accuracy: 0.5437956204379562
# 18/18 [==============================] - 0s 339us/step - loss: 1.3303
# Test loss: 1.3303035497665405

# %% [markdown]
# ### BIA

# %%
grp = "BIA"

# %%
# pre-processing: all columns can be scaled using standard scaler

for col in col_groups["BIA"]:
    if col == "BIA-BIA_Fat":
        data_orig[col] = data_orig[[col]]/100
        data_basic_impute[col] = data_basic_impute[[col]]/100
        data_knn_impute[col] = data_knn_impute[[col]]/100
    elif 'categorical' in data_dict.Type[data_dict.Field == col].values[0]:
        # convert to one-hot
        dummies = pd.get_dummies(data_orig[col],prefix=col).astype(int)
        data_orig = pd.concat([data_orig, dummies], axis=1)
        data_orig.drop(labels=col,axis=1)
        dummies = pd.get_dummies(data_basic_impute[col],prefix=col).astype(int)
        data_basic_impute = pd.concat([data_basic_impute, dummies], axis=1)
        data_basic_impute.drop(labels=col,axis=1)
        dummies = pd.get_dummies(data_knn_impute[col],prefix=col).astype(int)
        data_knn_impute = pd.concat([data_knn_impute, dummies], axis=1)
        data_knn_impute.drop(labels=col,axis=1)
    else:
        scaler = StandardScaler()
        scaler.fit(data_ref[[col]])
        data_orig[col] = scaler.transform(data_orig[[col]])
        data_basic_impute[col] = scaler.transform(data_basic_impute[[col]])
        data_knn_impute[col] = scaler.transform(data_knn_impute[[col]])

# add one-hot column names to col_groups definition
col_groups["BIA"] = [col for col in data_orig.columns if "BIA" in col]

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1048, 24)
# X_val shape (344, 24)
# X_test shape (355, 24)
# y_train shape (1048,)
# y_val shape (344,)
# y_test shape (355,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 12/12 [==============================] - 0s 336us/step
# Test accuracy: 0.5774647887323944
# 12/12 [==============================] - 0s 353us/step - loss: 0.9049
# Test loss: 0.9049416780471802

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1048, 24)
# X_val shape (344, 24)
# X_test shape (355, 24)
# y_train shape (1048,)
# y_val shape (344,)
# y_test shape (355,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 12/12 [==============================] - 0s 320us/step
# Test accuracy: 0.5774647887323944
# 12/12 [==============================] - 0s 356us/step - loss: 0.9049
# Test loss: 0.9049416780471802

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 24)
# X_val shape (547, 24)
# X_test shape (548, 24)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 308us/step
# Test accuracy: 0.5894160583941606
# 18/18 [==============================] - 0s 357us/step - loss: 0.9007
# Test loss: 0.9006726145744324

# %% [markdown]
# ### PAQ

# %%
grp = "PAQ"

# %%
# pre-processing: all columns can be scaled using standard scaler

for col in col_groups["PAQ"]:
    scaler = StandardScaler()
    scaler.fit(data_ref[[col]])
    data_orig[col] = scaler.transform(data_orig[[col]])
    data_basic_impute[col] = scaler.transform(data_basic_impute[[col]])
    data_knn_impute[col] = scaler.transform(data_knn_impute[[col]])

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1074, 1)
# X_val shape (353, 1)
# X_test shape (375, 1)
# y_train shape (1074,)
# y_val shape (353,)
# y_test shape (375,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 12/12 [==============================] - 0s 320us/step
# Test accuracy: 0.43466666666666665
# 12/12 [==============================] - 0s 386us/step - loss: 1.3837
# Test loss: 1.383686900138855

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1074, 1)
# X_val shape (353, 1)
# X_test shape (375, 1)
# y_train shape (1074,)
# y_val shape (353,)
# y_test shape (375,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 12/12 [==============================] - 0s 338us/step
# Test accuracy: 0.43466666666666665
# 12/12 [==============================] - 0s 365us/step - loss: 1.3837
# Test loss: 1.383686900138855

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 1)
# X_val shape (547, 1)
# X_test shape (548, 1)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 305us/step
# Test accuracy: 0.4051094890510949
# 18/18 [==============================] - 0s 347us/step - loss: 1.3842
# Test loss: 1.3842495679855347

# %% [markdown]
# ### SDS

# %%
grp = "SDS"

# %%
# raw and T are redundant: use only raw

col_groups["SDS"] = ["SDS-SDS_Total_Raw"]

# CGAS-CGAS_Score: scale from 0 to 100
data_orig["SDS-SDS_Total_Raw"] = data_orig[["SDS-SDS_Total_Raw"]]/100
data_basic_impute["SDS-SDS_Total_Raw"] = data_basic_impute[["SDS-SDS_Total_Raw"]]/100
data_knn_impute["SDS-SDS_Total_Raw"] = data_knn_impute[["SDS-SDS_Total_Raw"]]/100

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1517, 1)
# X_val shape (496, 1)
# X_test shape (514, 1)
# y_train shape (1517,)
# y_val shape (496,)
# y_test shape (514,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 17/17 [==============================] - 0s 298us/step
# Test accuracy: 0.6050583657587548
# 17/17 [==============================] - 0s 345us/step - loss: 1.0165
# Test loss: 1.016506552696228

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1517, 1)
# X_val shape (496, 1)
# X_test shape (514, 1)
# y_train shape (1517,)
# y_val shape (496,)
# y_test shape (514,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 17/17 [==============================] - 0s 304us/step
# Test accuracy: 0.6050583657587548
# 17/17 [==============================] - 0s 356us/step - loss: 1.0165
# Test loss: 1.016506552696228

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 1)
# X_val shape (547, 1)
# X_test shape (548, 1)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 313us/step
# Test accuracy: 0.6040145985401459
# 18/18 [==============================] - 0s 345us/step - loss: 1.0153
# Test loss: 1.0153477191925049

# %% [markdown]
# ### PreInt

# %%
grp = "PreInt"

# %%
# pre-processing: all columns can be scaled using standard scaler

for col in col_groups["PreInt"]:
    # convert to one-hot
    dummies = pd.get_dummies(data_orig[col],prefix=col).astype(int)
    data_orig = pd.concat([data_orig, dummies], axis=1)
    data_orig.drop(labels=col,axis=1)
    dummies = pd.get_dummies(data_basic_impute[col],prefix=col).astype(int)
    data_basic_impute = pd.concat([data_basic_impute, dummies], axis=1)
    data_basic_impute.drop(labels=col,axis=1)
    dummies = pd.get_dummies(data_knn_impute[col],prefix=col).astype(int)
    data_knn_impute = pd.concat([data_knn_impute, dummies], axis=1)
    data_knn_impute.drop(labels=col,axis=1)

# add one-hot column names to col_groups definition
col_groups["PreInt"] = [col for col in data_orig.columns if "PreInt" in col]

# %% [markdown]
# #### data_orig model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_orig)
results.loc["n_orig",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1594, 5)
# X_val shape (528, 5)
# X_test shape (532, 5)
# y_train shape (1594,)
# y_val shape (528,)
# y_test shape (532,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_orig",grp] = accuracy
# Out:
# 17/17 [==============================] - 0s 314us/step
# Test accuracy: 0.6015037593984962
# 17/17 [==============================] - 0s 340us/step - loss: 0.9009
# Test loss: 0.9009249210357666

# %% [markdown]
# #### data_basic_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_basic_impute)
results.loc["n_basic_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1594, 5)
# X_val shape (528, 5)
# X_test shape (532, 5)
# y_train shape (1594,)
# y_val shape (528,)
# y_test shape (532,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_basic_impute",grp] = accuracy
# Out:
# 17/17 [==============================] - 0s 310us/step
# Test accuracy: 0.6015037593984962
# 17/17 [==============================] - 0s 395us/step - loss: 0.9009
# Test loss: 0.9009249210357666

# %% [markdown]
# #### data_knn_impute model

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(col_groups[grp], data_knn_impute)
results.loc["n_knn_impute",grp] = X_train.shape[0] + X_val.shape[0] + X_test.shape[0]
# Out:
# X_train shape (1641, 5)
# X_val shape (547, 5)
# X_test shape (548, 5)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")

results.loc["data_knn_impute",grp] = accuracy
# Out:
# 18/18 [==============================] - 0s 319us/step
# Test accuracy: 0.6021897810218978
# 18/18 [==============================] - 0s 396us/step - loss: 0.8948
# Test loss: 0.894768476486206

# %% [markdown]
# # Final Results

# %%
results
# Out:
#                    Basic_Demos         CGAS     Physical  Fitness_Endurance  \
# n_orig             2736.000000  2342.000000  2464.000000         727.000000
# data_orig             0.437956     0.595699     0.493014           0.337748
# n_basic_impute     2736.000000  2342.000000  2465.000000                NaN
# data_basic_impute     0.437956     0.595699     0.497006                NaN
# n_knn_impute       2736.000000  2736.000000  2736.000000                NaN
# data_knn_impute       0.437956     0.604015     0.503650                NaN
#
#                            FGC          BIA          PAQ          SDS  \
# n_orig             1901.000000  1747.000000  1802.000000  2527.000000
# data_orig             0.550000     0.577465     0.434667     0.605058
# n_basic_impute     1901.000000  1747.000000  1802.000000  2527.000000
# data_basic_impute     0.550000     0.577465     0.434667     0.605058
# n_knn_impute       2736.000000  2736.000000  2736.000000  2736.000000
# data_knn_impute       0.543796     0.589416     0.405109     0.604015
#
#                         PreInt
# n_orig             2654.000000
# data_orig             0.601504
# n_basic_impute     2654.000000
# data_basic_impute     0.601504
# n_knn_impute       2736.000000
# data_knn_impute       0.602190

# %% [markdown]
# # Everything, imputed

# %% [markdown]
# (but no fitness endurance)

# %%
feat_cols = list(itertools.chain.from_iterable(col_groups.values()))
feat_cols = [col for col in feat_cols if "Fitness_Endurance" not in col]

# %%
# get_data
X_train, y_train, X_val, y_val, X_test, y_test = get_data(feat_cols, data_knn_impute)
# Out:
# X_train shape (1641, 43)
# X_val shape (547, 43)
# X_test shape (548, 43)
# y_train shape (1641,)
# y_val shape (547,)
# y_test shape (548,)

# %%
# build model
model = build_multiclass_model(X_train)

# fit model
history = model.fit(
  x = X_train,
  y = y_train,
  validation_data=(X_val, y_val),
  epochs=50,
  batch_size=10,
  verbose=0)

# %%
fig,ax = plt.subplots(1,1)
ax.plot(np.arange(50),history.history['loss'],label="Loss")
ax.plot(np.arange(50),history.history['val_loss'],label="Validation Loss")
ax.legend()
plt.show()

test_preds = model.predict(X_test)
test_preds_labels = np.argmax(test_preds, axis=1)
accuracy = np.mean(test_preds_labels == y_test)
print(f"Test accuracy: {accuracy}")
test_loss = model.evaluate(x=X_test, y=y_test)
print(f"Test loss: {test_loss}")
# Out:
# 18/18 [==============================] - 0s 317us/step
# Test accuracy: 0.6113138686131386
# 18/18 [==============================] - 0s 346us/step - loss: 0.8696
# Test loss: 0.8696448802947998

# %% [markdown]
# This is just barely the best model out of all of them.
